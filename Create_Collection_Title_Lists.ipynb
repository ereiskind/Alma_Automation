# %% [markdown]
# # Create Title List for Collection

# %% [markdown]
# ## 1. Gather Both Title and Portfolio Listings
# 1. Find the collection
# 2. Click into the collection's portfolio list
# 3. Download the Excel extended export of the portfolio list
# 4. Upload the Excel file to OpenRefine
# 5. Paste the project name below and run the cell

# %%
portfolio_project = ""

# %% [markdown]
# *If no set for the collection exists*
#
# 6. Copy the collection ID
# 7. Perform advanced search
#    * Search in Electronic Titles
#    * Electronic Collection PID Equals _collection ID_
# 8. Save search results as set

# %% [markdown]
# ## 2. Export Collection Title Set
# 1. Start "Export Bibliographic Records" job
# 2. Select electronic title set corresponding to collection
# 3. On "Enter Task Parameters" page, in "Expand routine" field, select "Add Holdings Information"
# 4. Run job
# 5. Export XML file
# 6. Upload the XML file to OpenRefine
# 7. Paste the project name below and run the cell

# %%
title_project = ""

# %% [markdown]
# ## 3. Convert XML to Tabular List
# 1. Apply Reformat_MARCXML_as_Tabular_Data.json to OpenRefine

# %% [markdown]
# ## 4. Add Information from Portfolio List to Title List
# > Done via cell cross
