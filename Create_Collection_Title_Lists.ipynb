# %% [markdown]
# # Create Title List for Collection

# %% [markdown]
# ## Overview/rough notes
# 1. Get set of titles in collection
#    1. get collection ID
#    2. search electrionic titles: electrionic collection PID: ID#
#    3. create set
# 2. job--bibliographic export of title set as xml with holdings
# 3. Convert above XML to tabular title list
# 4. Add further details w/ excel downloads of portfolio list from collection and/or search of portfolios for collection ID #

# %% [markdown]
# > For going from XML to table, start with "Apply Reformat_MARCXML_as_Tabular_Data.json to OpenRefine"
