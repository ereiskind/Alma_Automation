# %% [markdown]
# # Organize a Portfolio's Title List
#
# > start rework notes
#
# * need set of all titles in collection based on collection ID to run BIB export job
# * use bib export job for the main BIB info
# * use excel export of portfolio list for portfolio info
# * URLs will need a URL export job
#
# > end rework notes
#
# 1. Import the file **how the file gets imported** with a unique project name
# 2. Set `BIB_Project_Name` in the cell below equal to the project name and run the cell

# %%
BIB_Project_Name = ""

# %% [markdown]
# 3. Apply Reformat_MARCXML_as_Tabular_Data.json to OpenRefine
