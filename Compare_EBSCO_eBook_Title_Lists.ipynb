# %% [markdown]
# # Compare EBSCO eBook Title Lists
# 1. Download "My Owned Titles" from ECM
# 2. Download *ebook title report with all titles--get specific details on this* from EBSCOadmin
# 3. Apply "Reformat_EBSCOadmin_Title_List.json" to title list from EBSCOadmin
# 4. Apply "Reformat_ECM_Title_List.json" to title list from ECM
